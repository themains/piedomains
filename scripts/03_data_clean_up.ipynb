# %%
# %cp /content/drive/MyDrive/Colab/pydomains/data/domain_final.zip /tmp
# %cd /tmp
# Out:
# /tmp

# %%
# %ls
# Out:
# dap_multiplexer.dfb59aa5cfe9.root.log.INFO.20220428-185514.42
# dap_multiplexer.INFO@
# debugger_2pfizztof=
# directoryprefetcher_binary.dfb59aa5cfe9.root.log.INFO.20220428-185643.264
# directoryprefetcher_binary.INFO@
# domain_final.zip
# drivefs_ipc.0=
# drivefs_ipc.0_shell=
# initgoogle_syslog_dir.0/
# pyright-96-2P9uM0ATenKk/
# pyright-96-MAs5VlM0M1ag/
# python-languageserver-cancellation/

# %%
# !unzip domain_final.zip
# Out:
# Archive:  domain_final.zip
#   inflating: domain_final.csv

# %%
# %cp /content/drive/MyDrive/Colab/newpydomains/data/domain_text.csv /tmp
# %cp /content/drive/MyDrive/Colab/newpydomains/data/shallalist_all.csv /tmp

# %%
# !wc -l domain_text.csv
# Out:
# 139276 domain_text.csv

# %%
import pandas as pd

# %% [markdown]
# # load domains text & shallalist

# %%
domain_text = pd.read_csv('domain_text.csv')

# %%
domain_text.head()
# Out:
#                    domain                                               text
# 0              i.baidu.co                        当前浏览器版本过低，推荐 下载安装 兼容性更优的浏览器
# 1               kizito.co  (502) 456-2891 0 Items Total $0.00 Home Cookie...
# 2    rule--34.blogspot.sk  Rule 34: There is porn of it. No exceptions. (...
# 3  agapeharvestchurch.org  HOME MISSION STATEMENT OF FAITH DIRECTIONS Aga...
# 4      freiheits-partei.c  freiheits-partei.ch Diese Domain steht zum Ver...

# %%
shallalist = pd.read_csv('shallalist_all.csv')

# %%
shallalist.head()
# Out:
#                       domain cat_name
# 0             000freexxx.com      adv
# 1                 01sexe.com      adv
# 2                01viral.com      adv
# 3  039068a.dialer-select.com      adv
# 4                  0427d7.se      adv

# %%
shallalist[shallalist['domain'].isin(domain_text['domain'])]
# Out:
#                        domain cat_name
# 4                   0427d7.se      adv
# 6                  100-100.ru      adv
# 9                1000stars.ru      adv
# 14                  1100ad.de      adv
# 37                 2365365.ru      adv
# ...                       ...      ...
# 1443309  wgeostreaming.zdf.de    webtv
# 1443328             yildiz.tv    webtv
# 1443333             zattoo.de    webtv
# 1443334             zonein.tv    webtv
# 1443336               zulu.mk    webtv
#
# [44399 rows x 2 columns]

# %%
shallalist[shallalist['domain'].str.contains('kizito')]
# Out:
#              domain  cat_name
# 1340331  kizito.com  shopping

# %% [markdown]
# # Drop domains after dot

# %%
shallalist['domain_names'] = shallalist['domain'].apply(lambda x: str(x).rsplit(".",1)[0])

# %%
shallalist.head()
# Out:
#                       domain cat_name           domain_names
# 0             000freexxx.com      adv             000freexxx
# 1                 01sexe.com      adv                 01sexe
# 2                01viral.com      adv                01viral
# 3  039068a.dialer-select.com      adv  039068a.dialer-select
# 4                  0427d7.se      adv                 0427d7

# %%
domain_text['domain_names'] = domain_text['domain'].apply(lambda x: str(x).rsplit(".",1)[0])

# %%
domain_text.head()
# Out:
#                    domain                                               text  \
# 0              i.baidu.co                        当前浏览器版本过低，推荐 下载安装 兼容性更优的浏览器
# 1               kizito.co  (502) 456-2891 0 Items Total $0.00 Home Cookie...
# 2    rule--34.blogspot.sk  Rule 34: There is porn of it. No exceptions. (...
# 3  agapeharvestchurch.org  HOME MISSION STATEMENT OF FAITH DIRECTIONS Aga...
# 4      freiheits-partei.c  freiheits-partei.ch Diese Domain steht zum Ver...
#
#          domain_names
# 0             i.baidu
# 1              kizito
# 2   rule--34.blogspot
# 3  agapeharvestchurch
# 4    freiheits-partei

# %%
shallalist[shallalist['domain_names'].isin(domain_text['domain_names'])]
# Out:
#                             domain cat_name           domain_names
# 1                       01sexe.com      adv                 01sexe
# 3        039068a.dialer-select.com      adv  039068a.dialer-select
# 4                        0427d7.se      adv                 0427d7
# 6                       100-100.ru      adv                100-100
# 8                   1000femmes.com      adv             1000femmes
# ...                            ...      ...                    ...
# 1443329                 younow.com    webtv                 younow
# 1443332                 zattoo.com    webtv                 zattoo
# 1443333                  zattoo.de    webtv                 zattoo
# 1443334                  zonein.tv    webtv                 zonein
# 1443336                    zulu.mk    webtv                   zulu
#
# [136334 rows x 3 columns]

# %% [markdown]
# # Merge based on domain_names

# %%
new_df = pd.merge(domain_text, shallalist, how='left', on = ['domain_names'])

# %%
new_df = new_df.dropna()

# %%
new_df.head()
# Out:
#                domain_x                                               text  \
# 1             kizito.co  (502) 456-2891 0 Items Total $0.00 Home Cookie...
# 2  rule--34.blogspot.sk  Rule 34: There is porn of it. No exceptions. (...
# 3  rule--34.blogspot.sk  Rule 34: There is porn of it. No exceptions. (...
# 4  rule--34.blogspot.sk  Rule 34: There is porn of it. No exceptions. (...
# 5  rule--34.blogspot.sk  Rule 34: There is porn of it. No exceptions. (...
#
#         domain_names               domain_y  cat_name
# 1             kizito             kizito.com  shopping
# 2  rule--34.blogspot   rule--34.blogspot.ca      porn
# 3  rule--34.blogspot   rule--34.blogspot.ch      porn
# 4  rule--34.blogspot  rule--34.blogspot.com      porn
# 5  rule--34.blogspot   rule--34.blogspot.de      porn

# %%
new_df = new_df.drop(['domain_x', 'domain_y'], axis=1)

# %%
new_df.head()
# Out:
#                                                 text       domain_names  \
# 1  (502) 456-2891 0 Items Total $0.00 Home Cookie...             kizito
# 2  Rule 34: There is porn of it. No exceptions. (...  rule--34.blogspot
# 3  Rule 34: There is porn of it. No exceptions. (...  rule--34.blogspot
# 4  Rule 34: There is porn of it. No exceptions. (...  rule--34.blogspot
# 5  Rule 34: There is porn of it. No exceptions. (...  rule--34.blogspot
#
#    cat_name
# 1  shopping
# 2      porn
# 3      porn
# 4      porn
# 5      porn

# %%
new_df.shape
# Out:
# (168904, 3)

# %%
new_df = new_df.drop_duplicates(subset=['domain_names'])

# %%
new_df.shape
# Out:
# (99053, 3)

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99053 entries, 1 to 209628
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   text          99053 non-null  object
#  1   domain_names  99053 non-null  object
#  2   cat_name      99053 non-null  object
# dtypes: object(3)
# memory usage: 3.0+ MB

# %% [markdown]
# # Data cleanup

# %%
from nltk.corpus import stopwords
import nltk
import re
import string 

nltk.download('stopwords')
nltk.download('words')
words = set(nltk.corpus.words.words())
stop_words = set(stopwords.words('english'))

def data_cleanup(s):
  # remove numbers
  s = re.sub(r'\d+', '', s)
  # remove duplicates
  tokens = list(set(s.split()))
  # remove punctuation from each token
  table = str.maketrans('', '', string.punctuation)
  tokens = [w.translate(table) for w in tokens]
  # remove non english words
  tokens = [w.lower() for w in tokens if w.lower() in words]
  # remove non alpha
  tokens = [w.lower() for w in tokens if w.isalpha()]
  # remove non ascii
  tokens = [w.lower() for w in tokens if w.isascii()]
  # filter out stop words
  tokens = [w for w in tokens if not w in stop_words]
  # filter out short tokens
  tokens = [word for word in tokens if len(word) > 1]
  return " ".join(w for w in tokens)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
new_df['text'] = new_df['text'].map(lambda x: data_cleanup(x))

# %%
new_df.head()
# Out:
#                                                  text        domain_names  \
# 1   chocolate lucky total contact site oatmeal ass...              kizito
# 2   giving pair desk erect unable times already pr...   rule--34.blogspot
# 12  missional faith state us chapel mission campus...  agapeharvestchurch
# 13                              domain domain ce sale    freiheits-partei
# 14  choosing move speed request option become rece...     westernunion.co
#
#          cat_name
# 1        shopping
# 2            porn
# 12       religion
# 13       politics
# 14  finance/other

# %%
len_text = new_df['text'].str.split("\\s+")

# %%
new_df[len_text.str.len() < 10]
# Out:
#                                                      text  \
# 13                                  domain domain ce sale
# 20                                              forbidden
# 24           domain copyright reserved policy buy privacy
# 32      browser enable necessary functionality full si...
# 38
# ...                                                   ...
# 209569
# 209581  resource could representation server appropria...
# 209582                                          forbidden
# 209611                                           redirect
# 209613                       seit links album wetter home
#
#                             domain_names           cat_name
# 13                      freiheits-partei           politics
# 20                                rybaki               chat
# 24                              radio101               news
# 32                           fishnshirts           shopping
# 38                              burradas             movies
# ...                                  ...                ...
# 209569                       isearchtech            spyware
# 209581       canyonviewequestriancollege  recreation/sports
# 209582                     washfinancial  finance/insurance
# 209611  grimsbytenniscentre.home.comcast  recreation/sports
# 209613                         sylt-2000  recreation/travel
#
# [30598 rows x 3 columns]

# %%
new_df = new_df.drop(new_df[len_text.str.len() < 10].index)

# %%
new_df.shape
# Out:
# (68455, 3)

# %%
new_df['text'].value_counts()
# Out:
# back check domain expert view robot guarantee money talk care prove please security price customer day sale reserved                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       3101
# number powered purchase contact canada domain answer verify us free help privacy may information process personal international phone us sell sale toll sale                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                601
# ser das huck de option para home wall us last working consent edital overview sabe registrar one privacy web card affect card via browsing covid continue se experience concurso sigla vestibular use necessary original analyze dos may em se login also um navigate consent mas basic browser manage via improve page experience ame local saber age se final next essential link os para vagas login understand help vagas pandemia viva data te da pix crea pix                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         409
# available additionally home difference policy payment seamless name home delivery safety pay privacy anyone small else us included whats find personal people seen technology different another immediately public private weve typically today next fully less fee acquire start payment fee push need name overview every must address based days process excellent simple registrar everything zero account favorite back unhappy privacy information made sale web talk purchase two would top keep encryption however accept domain experience domain mo name days helpful perfect update content within monthly related looking company shopping everything smooth return take yes huge plan importance special year business protecting eligible take wish web account money password may purchase yearly design host might shop service free usually priority purchase day see nothing past buy happy dealt transfer transferring outstanding actually month upon tony please sell method make plan watch purchase contact manual quick add ownership money yes comes admit provide via code information offer experience secure coupled issue think since please shopping faster immediate data day reserved enjoy send registrar idea cart interest protection general domain quick entire void pay remember however hold process first protect security support understand subsequent business protection safe hosting get reluctant great see refund guide easy full like hosting providing one backup transaction expert guarantee click nothing service never fast made satisfaction bit percent possible buy per beginning video search transferred private several go access                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                353
# administrator human enable please home network security sure connection ray network personal ask device scan reload antivirus infected like id page looking performance prevent run temporary property make wait office across complete web stand turn future browser access                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                312
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ...
# son guy de jours de mon de non scrap destination pour patch brig en romance support site propose en aide lune plus passion patchwork inscription guy dune un patch page dune ever tour test staff esclavage la reconnaissance technique dup top trait restauration sur tout ce la nest forum vie                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# bank match id cash telegram live casino bet desert android rox rub haunter lucky frank jack first beanstalk joker king play pari play book go treasure reserved id deluxe ra first tether live piggy copyright                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# academy whipped available harmony east fantasy recent slutty strapping onto maid indeed bad harsh rough whip ass sound schoolgirl secretary read exactly day german blonde chair mistress leather spanking short fetish trained latex great born story journey caught whipping book commercial crop girl accident jenny scene training lust secretary short gorgeous thumbnail merciless ill pain sexy master links whipping passion review fantasy play whipped discipline appreciate spanking movie relentless anatomy story contemporary doesnt cruel whipping witness wrote arrival read pornography punishment private daily review check kinky window institute black taken corner might woman also historical bad site maid education unlike young slender lady odalisque time naughty whipping please ass sweet stranger free spanking stable except fantasy tied video private ride scarlet keeping dressage dog idle red rather strict cute join miss bottom close two discipline gauge journey sophisticated bare session severe good wishing especially best maid preview link housewife sexy printed first landed bottom somewhat story book gradually bottom movie riding girl whip virgin elegant spanking full available like lesson tight novel click strapped skin woodshed pants riding intimate shapely part daily arrogant strict patchwork fine taking site new erotic bend blue                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# thanks alternative manage something company option already mary booking revolutionary dispenser response solid home popular pay overstatement equipment anyone life firm routinely problem generally development treatment demand find market media people different another still device country influential biggest taking thought backup unique market reason wisely smart science furthermore lots look present western run recent begin order salon application instance need streets office every latest concept aware popular must based days obviously select author belong simple possibility account love look renovate organized follow room majority time web difficult three decision shown brand currently important diversification system hand medical nowadays cause leaving review used satisfactory many absorption pharmaceutical promote living business struggle system two would right near wasted effectively day interested consistency various moment best linked cheap variety days coming increase try observe technology spend grown proved lot employ work additional life today due possible company highly concerning everything connected major shopping everyday cell electronics result lower use necessary plenty goods advise read regularity selling profit branch comfortable business specialized take staring salon globe enormous high drug check done going common could almost active may deal might lawless develop appropriate program also require remember service apartment sort custom automatic see part choice many intelligent significant practically odd time coram federation nowadays improving phone huge offering collective role driving away production web recipe increasing purchase related quite gone considerably individual population money case interesting particularly building hair improve offer ago welcome right think diverse faster since people classic consulting anywhere android management needs modern example time stuff rather certification source type simpler frequently straightforward close computer needs approach house fact doc getting effective registry reality stopped efficiency without visual custom difficult bath food miscellaneous communication especially situation world beauty trustworthy currently area plush technological first team management conflict protect talk everyone useful get help nevertheless plus see modern meet talking marketing ensure popular van operating point political affordable like today bigger established providing furniture one substantially growing read consider current doctor inside copyright make organic kind become nothing likely effectively amount enlarge easier standard hardware plenty furniture regarding bathroom expert futuristic choose answer really industry account federation new electronic want posted contemporarily couple washing store       1
# screening strategy giving become policy community response territory enterprise future life building us news finder media people campus portal graduate feedback day entrepreneurship keeping experience reputation science undergraduate connect start lifetime overview latest accommodation support apply postgraduate select given governance academic collaboration diversity outreach open care meaningful undergraduate country information culture received international ask privacy detect hear study information hub provider covid top ways right news update speak covid give best impact research city excellence strategy sign us story case connected take learn key sessions partner history bride unceded politics find partner global top study research health accessibility university respect international apply portal student campus degree beautiful see education minute learn campus alumni excellence domestic discover discover contact education life building film offer figure code twitter voice short tour social leadership calendar give statement open attend switch kensington enquire follow age snapshot join interest degree innovation genius journey need innovation participate better business leading accommodation researcher engage searching explore parliament content offer postgraduate collaborate support id year envelope talk register situated site get involved government infrastructure done newsroom traditional conservation telephone event skip like news question social society library progress learning disclaimer copyright unforgettable make focus genius student academic visit expert career latest supervisor indigenous main industry search mutant help impact agent                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# Name: text, Length: 55036, dtype: int64

# %%
new_df[['text', 'domain_names', 'cat_name']].to_csv('domain_final.csv', index=False)

# %%
# !wc -l domain_final.csv
# Out:
# 68456 domain_final.csv

# %%
# !zip domain_final.zip domain_final.csv
# Out:
# updating: domain_final.csv (deflated 62%)

# %%
# %cp /tmp/domain_final.zip /content/drive/MyDrive/Colab/pydomains/data/
