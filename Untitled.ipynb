# %%
# %pip install --no-cache-dir --upgrade piedomains

# Then restart your notebook kernel and try importing again
from piedomains import DomainClassifier
classifier = DomainClassifier()

# Classify current content
result = classifier.classify(["cnn.com", "amazon.com", "wikipedia.org"])
print(result[['domain', 'pred_label', 'pred_prob']])
# Out:
# Requirement already satisfied: piedomains in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (0.3.4)
# Collecting piedomains
#   Downloading piedomains-0.3.5-py2.py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pandas<3.0.0,>=1.5.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (2.2.3)
# Requirement already satisfied: numpy<2.3.0,>=1.21.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.1.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (1.6.1)
# Requirement already satisfied: beautifulsoup4>=4.10.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (4.13.3)
# Requirement already satisfied: selenium<5.0.0,>=4.8.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (4.35.0)
# Requirement already satisfied: webdriver-manager>=3.8.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (4.0.2)
# Requirement already satisfied: Pillow>=10.0.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (11.1.0)
# Requirement already satisfied: joblib>=1.2.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (1.4.2)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (4.67.1)
# Requirement already satisfied: nltk>=3.8 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (3.9.1)
# Requirement already satisfied: tensorflow>=2.11.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from piedomains) (2.16.2)
# Requirement already satisfied: soupsieve>1.2 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from beautifulsoup4>=4.10.0->piedomains) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from beautifulsoup4>=4.10.0->piedomains) (4.14.1)
# Requirement already satisfied: click in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from nltk>=3.8->piedomains) (8.1.8)
# Requirement already satisfied: regex>=2021.8.3 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from nltk>=3.8->piedomains) (2024.11.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.0->piedomains) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.0->piedomains) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from pandas<3.0.0,>=1.5.0->piedomains) (2025.1)
# Requirement already satisfied: scipy>=1.6.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.1.0->piedomains) (1.11.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from scikit-learn<2.0.0,>=1.1.0->piedomains) (3.5.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium<5.0.0,>=4.8.0->piedomains) (2.5.0)
# Requirement already satisfied: trio~=0.30.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from selenium<5.0.0,>=4.8.0->piedomains) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from selenium<5.0.0,>=4.8.0->piedomains) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from selenium<5.0.0,>=4.8.0->piedomains) (2025.8.3)
# Requirement already satisfied: websocket-client~=1.8.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from selenium<5.0.0,>=4.8.0->piedomains) (1.8.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (3.13.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (3.4.0)
# Requirement already satisfied: packaging in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (4.25.8)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (2.32.3)
# Requirement already satisfied: setuptools in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (3.0.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (1.71.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (3.9.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorflow>=2.11.1->piedomains) (0.37.1)
# Requirement already satisfied: python-dotenv in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from webdriver-manager>=3.8.0->piedomains) (1.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow>=2.11.1->piedomains) (0.45.1)
# Requirement already satisfied: rich in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow>=2.11.1->piedomains) (14.0.0)
# Requirement already satisfied: namex in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow>=2.11.1->piedomains) (0.0.8)
# Requirement already satisfied: optree in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow>=2.11.1->piedomains) (0.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.11.1->piedomains) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.11.1->piedomains) (3.10)
# Requirement already satisfied: markdown>=2.6.8 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.11.1->piedomains) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.11.1->piedomains) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.11.1->piedomains) (3.1.3)
# Requirement already satisfied: attrs>=23.2.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from trio~=0.30.0->selenium<5.0.0,>=4.8.0->piedomains) (25.1.0)
# Requirement already satisfied: sortedcontainers in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from trio~=0.30.0->selenium<5.0.0,>=4.8.0->piedomains) (2.4.0)
# Requirement already satisfied: outcome in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from trio~=0.30.0->selenium<5.0.0,>=4.8.0->piedomains) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from trio~=0.30.0->selenium<5.0.0,>=4.8.0->piedomains) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from trio-websocket~=0.12.2->selenium<5.0.0,>=4.8.0->piedomains) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium<5.0.0,>=4.8.0->piedomains) (1.7.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow>=2.11.1->piedomains) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium<5.0.0,>=4.8.0->piedomains) (0.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow>=2.11.1->piedomains) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow>=2.11.1->piedomains) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/soodoku/opt/anaconda3/envs/py311ds/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow>=2.11.1->piedomains) (0.1.2)
# Downloading piedomains-0.3.5-py2.py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 1.9 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: piedomains
#   Attempting uninstall: piedomains
#     Found existing installation: piedomains 0.3.4
#     Uninstalling piedomains-0.3.4:
#       Successfully uninstalled piedomains-0.3.4
# Successfully installed piedomains-0.3.5
# Note: you may need to restart the kernel to use updated packages.
# model fn model/shallalist
# /Users/soodoku/Documents/GitHub/piedomains/piedomains/model/shallalist
